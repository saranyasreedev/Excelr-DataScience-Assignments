# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing, metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# # 1 - Business Problem
#
# Prepare a classification model using Naive Bayes for salary data

# %% [markdown]
# ## 2 - Data collection and description

# %%
test_tmp = pd.read_csv("/content/SalaryData_Test.csv")
train_tmp = pd.read_csv("/content/SalaryData_Train.csv")

# %%
test = test_tmp.copy()
train = train_tmp.copy()

# %%
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
str_c = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
number = LabelEncoder()

for i in str_c:
    train[i]= number.fit_transform(train[i])
    test[i]=number.fit_transform(test[i])

# %%
test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2    >50K
# 3    >50K
# 4   <=50K

# %%
train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
mapping = {' >50K': 1, ' <=50K': 2}

# %%
df = train.append(test)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %% [markdown]
# ## EDA

# %%
df1.shape
# Out:
# (45221, 14)

# %%
df1.describe().T
# Out:
#                  count         mean          std   min   25%   50%   75%  \
# age            45221.0    38.548086    13.217981  17.0  28.0  37.0  47.0
# workclass      45221.0     2.204507     0.958132   0.0   2.0   2.0   2.0
# education      45221.0    10.313217     3.816992   0.0   9.0  11.0  12.0
# educationno    45221.0    10.118463     2.552909   1.0   9.0  10.0  13.0
# maritalstatus  45221.0     2.585148     1.500460   0.0   2.0   2.0   4.0
# occupation     45221.0     5.969572     4.026444   0.0   2.0   6.0   9.0
# relationship   45221.0     1.412684     1.597242   0.0   0.0   1.0   3.0
# race           45221.0     3.680281     0.832361   0.0   4.0   4.0   4.0
# sex            45221.0     0.675062     0.468357   0.0   0.0   1.0   1.0
# capitalgain    45221.0  1101.454700  7506.511295   0.0   0.0   0.0   0.0
# capitalloss    45221.0    88.548617   404.838249   0.0   0.0   0.0   0.0
# hoursperweek   45221.0    40.938038    12.007640   1.0  40.0  40.0  45.0
# native         45221.0    35.431503     5.931380   0.0  37.0  37.0  37.0
#
#                    max
# age               90.0
# workclass          6.0
# education         15.0
# educationno       16.0
# maritalstatus      6.0
# occupation        13.0
# relationship       5.0
# race               4.0
# sex                1.0
# capitalgain    99999.0
# capitalloss     4356.0
# hoursperweek      99.0
# native            39.0

# %%
df1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %% [markdown]
# Correlation

# %%
cor = df1.corr()
cor
# Out:
#                     age  workclass  education  educationno  maritalstatus  \
# age            1.000000   0.085890  -0.003497     0.037623      -0.271616
# workclass      0.085890   1.000000   0.017852     0.040778      -0.033217
# education     -0.003497   0.017852   1.000000     0.347451      -0.041547
# educationno    0.037623   0.040778   0.347451     1.000000      -0.064986
# maritalstatus -0.271616  -0.033217  -0.041547    -0.064986       1.000000
# occupation    -0.004474   0.017508  -0.033500     0.089686       0.016399
# relationship  -0.247561  -0.065048  -0.013190    -0.088431       0.180430
# race           0.023781   0.049767   0.011446     0.031655      -0.070311
# sex            0.082040   0.069633  -0.027531     0.003416      -0.119982
# capitalgain    0.079682   0.034542   0.029893     0.126907      -0.042397
# capitalloss    0.059426   0.008261   0.016740     0.081741      -0.034940
# hoursperweek   0.101992   0.051366   0.060890     0.146206      -0.183178
# native        -0.002879   0.003889   0.078800     0.094125      -0.022880
#
#                occupation  relationship      race       sex  capitalgain  \
# age             -0.004474     -0.247561  0.023781  0.082040     0.079682
# workclass        0.017508     -0.065048  0.049767  0.069633     0.034542
# education       -0.033500     -0.013190  0.011446 -0.027531     0.029893
# educationno      0.089686     -0.088431  0.031655  0.003416     0.126907
# maritalstatus    0.016399      0.180430 -0.070311 -0.119982    -0.042397
# occupation       1.000000     -0.051644 -0.000026  0.056626     0.019435
# relationship    -0.051644      1.000000 -0.118588 -0.582977    -0.056817
# race            -0.000026     -0.118588  1.000000  0.088949     0.014079
# sex              0.056626     -0.582977  0.088949  1.000000     0.047441
# capitalgain      0.019435     -0.056817  0.014079  0.047441     1.000000
# capitalloss      0.015271     -0.058485  0.020917  0.046639    -0.032095
# hoursperweek     0.016160     -0.259194  0.044739  0.231427     0.083880
# native          -0.002628     -0.007016  0.126192 -0.004653     0.007641
#
#                capitalloss  hoursperweek    native
# age               0.059426      0.101992 -0.002879
# workclass         0.008261      0.051366  0.003889
# education         0.016740      0.060890  0.078800
# educationno       0.081741      0.146206  0.094125
# maritalstatus    -0.034940     -0.183178 -0.022880
# occupation        0.015271      0.016160 -0.002628
# relationship     -0.058485     -0.259194 -0.007016
# race              0.020917      0.044739  0.126192
# sex               0.046639      0.231427 -0.004653
# capitalgain      -0.032095      0.083880  0.007641
# capitalloss       1.000000      0.054220  0.006484
# hoursperweek      0.054220      1.000000  0.007585
# native            0.006484      0.007585  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True)

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
print("Skew: {}".format(df1['educationno'].skew()))
print("Kurtosis: {}".format(df1['educationno'].kurtosis()))
# Out:
# Skew: -0.31062061074424
# Kurtosis: 0.6350448194491634

# %%
plt.figure(figsize=(16,5))
df1 = df1.reset_index()
ax = sns.kdeplot(df1['educationno'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()

# %% [markdown]
# The Data is negatively skewed and has low kurtosis value
#
# Most of people have eduction Number of years of education 8 - 11

# %%
dfa = df_tmp[df_tmp.columns[0:13]]
dfa
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 30156   27        Private     Assoc-acdm           12   Married-civ-spouse
# 30157   40        Private        HS-grad            9   Married-civ-spouse
# 30158   58        Private        HS-grad            9              Widowed
# 30159   22        Private        HS-grad            9        Never-married
# 30160   52   Self-emp-inc        HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0       Machine-op-inspct       Own-child   Black     Male            0
# 1         Farming-fishing         Husband   White     Male            0
# 2         Protective-serv         Husband   White     Male            0
# 3       Machine-op-inspct         Husband   Black     Male         7688
# 4           Other-service   Not-in-family   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native
# 0                0            40   United-States
# 1                0            50   United-States
# 2                0            40   United-States
# 3                0            40   United-States
# 4                0            30   United-States
# ...            ...           ...             ...
# 30156            0            38   United-States
# 30157            0            40   United-States
# 30158            0            40   United-States
# 30159            0            20   United-States
# 30160            0            40   United-States
#
# [45221 rows x 13 columns]

# %%
obj_colum = dfa.select_dtypes(include='object').columns.tolist()
obj_colum
# Out:
# ['workclass',
#  'education',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native']

# %%
plt.figure(figsize=(15,25))
for i,col in enumerate(obj_colum,1):
  plt.subplot(4,4,i)
  sns.countplot(data=dfa,y=col)
  plt.ylabel(col)
  plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,25))
for i,col in enumerate(obj_colum,1):
  plt.subplot(4,4,i)
  df_tmp[col].value_counts(normalize=True).plot.bar()
  plt.ylabel(col)
  plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()

# %% [markdown]
# Majority of the workclass is in Private Sector
#
# Also for education majority of the people have HS graduation or some college degree

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()
num_columns
# Out:
# ['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek']

# %%
df = df.reset_index()

# %%
plt.figure(figsize=(10,10))
for i,col in enumerate(num_columns,1):
    plt.subplot(3,3,i)
    sns.kdeplot(df[col],color='g',shade=True)
plt.tight_layout() 
plt.show()
num_data = df[num_columns]

# %%
plt.figure(figsize=(10,10))
for i,col in enumerate(num_columns,1):
    plt.subplot(3,3,i)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]

# %%
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#                age  educationno  capitalgain  capitalloss  hoursperweek
# skewness  0.532784    -0.310621    11.788871     4.517536      0.340536
# kurtosis -0.155931     0.635045   150.147899    19.376085      3.201287

# %% [markdown]
# ## 3 - Naive Bayes

# %%
df1
# Out:
#        index  age  workclass  education  educationno  maritalstatus  \
# 0          0   39          5          9           13              4
# 1          1   50          4          9           13              2
# 2          2   38          2         11            9              0
# 3          3   53          2          1            7              2
# 4          4   28          2          9           13              2
# ...      ...  ...        ...        ...          ...            ...
# 45216  15055   33          2          9           13              4
# 45217  15056   39          2          9           13              0
# 45218  15057   38          2          9           13              2
# 45219  15058   44          2          9           13              0
# 45220  15059   35          3          9           13              2
#
#        occupation  relationship  race  sex  capitalgain  capitalloss  \
# 0               0             1     4    1         2174            0
# 1               3             0     4    1            0            0
# 2               5             1     4    1            0            0
# 3               5             0     2    1            0            0
# 4               9             5     2    0            0            0
# ...           ...           ...   ...  ...          ...          ...
# 45216           9             3     4    1            0            0
# 45217           9             1     4    0            0            0
# 45218           9             0     4    1            0            0
# 45219           0             3     1    1         5455            0
# 45220           3             0     4    1            0            0
#
#        hoursperweek  native  Salary
# 0                40      37   <=50K
# 1                13      37   <=50K
# 2                40      37   <=50K
# 3                40      37   <=50K
# 4                40       4   <=50K
# ...             ...     ...     ...
# 45216            40      37   <=50K
# 45217            36      37   <=50K
# 45218            50      37   <=50K
# 45219            40      37   <=50K
# 45220            60      37    >50K
#
# [45221 rows x 15 columns]

# %%
X = df1.iloc[:,0:14]
Y = df1.iloc[:,14]

# %%
X
# Out:
#        index  age  workclass  education  educationno  maritalstatus  \
# 0          0   39          5          9           13              4
# 1          1   50          4          9           13              2
# 2          2   38          2         11            9              0
# 3          3   53          2          1            7              2
# 4          4   28          2          9           13              2
# ...      ...  ...        ...        ...          ...            ...
# 45216  15055   33          2          9           13              4
# 45217  15056   39          2          9           13              0
# 45218  15057   38          2          9           13              2
# 45219  15058   44          2          9           13              0
# 45220  15059   35          3          9           13              2
#
#        occupation  relationship  race  sex  capitalgain  capitalloss  \
# 0               0             1     4    1         2174            0
# 1               3             0     4    1            0            0
# 2               5             1     4    1            0            0
# 3               5             0     2    1            0            0
# 4               9             5     2    0            0            0
# ...           ...           ...   ...  ...          ...          ...
# 45216           9             3     4    1            0            0
# 45217           9             1     4    0            0            0
# 45218           9             0     4    1            0            0
# 45219           0             3     1    1         5455            0
# 45220           3             0     4    1            0            0
#
#        hoursperweek  native
# 0                40      37
# 1                13      37
# 2                40      37
# 3                40      37
# 4                40       4
# ...             ...     ...
# 45216            40      37
# 45217            36      37
# 45218            50      37
# 45219            40      37
# 45220            60      37
#
# [45221 rows x 14 columns]

# %%
Y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 45216     <=50K
# 45217     <=50K
# 45218     <=50K
# 45219     <=50K
# 45220      >50K
# Name: Salary, Length: 45221, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# %%
y_test
# Out:
# 41386     <=50K
# 35278     <=50K
# 26950     <=50K
# 29133     <=50K
# 41793     <=50K
#           ...
# 39916      >50K
# 29313     <=50K
# 34409     <=50K
# 27489     <=50K
# 19057     <=50K
# Name: Salary, Length: 4523, dtype: object

# %%
y_train
# Out:
# 1402      <=50K
# 14614     <=50K
# 13931     <=50K
# 2958      <=50K
# 20252     <=50K
#           ...
# 30403     <=50K
# 21243      >50K
# 42613      >50K
# 43567      >50K
# 2732      <=50K
# Name: Salary, Length: 40698, dtype: object

# %%
x_test
# Out:
#        index  age  workclass  education  educationno  maritalstatus  \
# 41386  11225   23          2          7           12              2
# 35278   5117   40          2         15           10              5
# 26950  26950   45          2          9           13              0
# 29133  29133   23          2         15           10              4
# 41793  11632   31          2         11            9              2
# ...      ...  ...        ...        ...          ...            ...
# 39916   9755   31          2         11            9              2
# 29313  29313   43          2         11            9              2
# 34409   4248   51          2         15           10              0
# 27489  27489   37          2         15           10              2
# 19057  19057   45          2         11            9              2
#
#        occupation  relationship  race  sex  capitalgain  capitalloss  \
# 41386           4             5     4    0            0            0
# 35278          12             3     4    0            0            0
# 26950           3             1     4    1            0            0
# 29133           5             3     4    1            0            0
# 41793           0             0     4    1            0            0
# ...           ...           ...   ...  ...          ...          ...
# 39916          13             0     4    1            0            0
# 29313          11             0     4    1            0            0
# 34409          11             4     2    0            0            0
# 27489          12             5     4    0         5013            0
# 19057           7             5     4    0            0            0
#
#        hoursperweek  native
# 41386            45      10
# 35278            32      37
# 26950            45      37
# 29133            20      37
# 41793            40      37
# ...             ...     ...
# 39916            45      37
# 29313            40      37
# 34409            50      37
# 27489            40      37
# 19057            35      37
#
# [4523 rows x 14 columns]

# %%
x_train
# Out:
#        index  age  workclass  education  educationno  maritalstatus  \
# 1402    1402   26          1          9           13              4
# 14614  14614   53          5         11            9              0
# 13931  13931   30          2         11            9              4
# 2958    2958   53          1         11            9              2
# 20252  20252   63          2          1            7              2
# ...      ...  ...        ...        ...          ...            ...
# 30403    242   26          2          9           13              4
# 21243  21243   51          2          7           12              2
# 42613  12452   64          4         11            9              2
# 43567  13406   48          2         15           10              2
# 2732    2732   34          2         11            9              0
#
#        occupation  relationship  race  sex  capitalgain  capitalloss  \
# 1402            9             1     4    1            0         2339
# 14614           3             1     4    1            0         1092
# 13931           0             4     4    1            0            0
# 2958            7             0     4    1            0         2002
# 20252          11             0     4    1            0            0
# ...           ...           ...   ...  ...          ...          ...
# 30403           0             3     4    0            0            0
# 21243           3             0     4    1            0            0
# 42613           9             0     4    1            0            0
# 43567           7             0     2    1            0            0
# 2732            2             1     4    1         3325            0
#
#        hoursperweek  native
# 1402             55      37
# 14614            40      37
# 13931            40      37
# 2958             45      37
# 20252            22      37
# ...             ...     ...
# 30403            40      37
# 21243            45      37
# 42613            60      37
# 43567            40      37
# 2732             35      37
#
# [40698 rows x 14 columns]

# %% [markdown]
# ## 3.1 - GaussianNB

# %%
clsfrgnb = GaussianNB()

# %%
clsfrgnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_gnb = clsfrgnb.predict(x_test)

# %%
y_pred_gnb
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
confusion_matrix(y_test, y_pred_gnb)
# Out:
# array([[3266,  170],
#        [ 725,  362]])

# %%
pd.crosstab(y_test.values.flatten(),clsfrgnb)
# Out:
# col_0   GaussianNB()
# row_0
#  <=50K          3436
#  >50K           1087

# %%
print ("Accuracy",np.mean(y_pred_gnb==y_test.values.flatten()))
# Out:
# Accuracy 0.8021224850762768

# %% [markdown]
# ## 3.2 - MultinomialNB

# %%
clsfrmnb = MultinomialNB()

# %%
clsfrmnb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred_mnb = clsfrmnb.predict(x_test)
y_pred_mnb
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
confusion_matrix(y_test, y_pred_mnb)
# Out:
# array([[3272,  164],
#        [ 814,  273]])

# %%
pd.crosstab(y_test.values.flatten(),clsfrmnb)
# Out:
# col_0   MultinomialNB()
# row_0
#  <=50K             3436
#  >50K              1087

# %%
print ("Accuracy",np.mean(y_pred_mnb==y_test.values.flatten()))
# Out:
# Accuracy 0.7837718328543002

# %% [markdown]
# ## 4 - Conclusion

# %% [markdown]
# GaussianNB Model has a better Accuracy, Thus we will use GaussianNB Classifier
