# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing, metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Company_Data.csv

# %% [markdown]
# # 1 - Business Problem
#
# Prepare a Random Forest model can be built with target variable Sale for company_data

# %% [markdown]
# # 2 - Data collection and description

# %%
data = pd.read_csv(r'Company_Data.csv')

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data1 = data.copy()

# %% [markdown]
# # EDA

# %%
data1.shape
# Out:
# (400, 11)

# %%
data1 = pd.get_dummies(data1, columns = ['ShelveLoc','Urban','US'])

# %%
data1.describe().T
# Out:
#                   count        mean         std   min     25%     50%     75%  \
# Sales             400.0    7.496325    2.824115   0.0    5.39    7.49    9.32
# CompPrice         400.0  124.975000   15.334512  77.0  115.00  125.00  135.00
# Income            400.0   68.657500   27.986037  21.0   42.75   69.00   91.00
# Advertising       400.0    6.635000    6.650364   0.0    0.00    5.00   12.00
# Population        400.0  264.840000  147.376436  10.0  139.00  272.00  398.50
# Price             400.0  115.795000   23.676664  24.0  100.00  117.00  131.00
# Age               400.0   53.322500   16.200297  25.0   39.75   54.50   66.00
# Education         400.0   13.900000    2.620528  10.0   12.00   14.00   16.00
# ShelveLoc_Bad     400.0    0.240000    0.427618   0.0    0.00    0.00    0.00
# ShelveLoc_Good    400.0    0.212500    0.409589   0.0    0.00    0.00    0.00
# ShelveLoc_Medium  400.0    0.547500    0.498362   0.0    0.00    1.00    1.00
# ...

# %%
data1.isnull().sum()
# Out:
# Sales               0
# CompPrice           0
# Income              0
# Advertising         0
# Population          0
# Price               0
# Age                 0
# Education           0
# ShelveLoc_Bad       0
# ShelveLoc_Good      0
# ShelveLoc_Medium    0
# Urban_No            0
# Urban_Yes           0
# US_No               0
# US_Yes              0
# dtype: int64

# %% [markdown]
# Correlation

# %%
cor = data1.corr()
cor
# Out:
#                      Sales  CompPrice    Income  Advertising  Population  \
# Sales             1.000000   0.064079  0.151951     0.269507    0.050471
# CompPrice         0.064079   1.000000 -0.080653    -0.024199   -0.094707
# Income            0.151951  -0.080653  1.000000     0.058995   -0.007877
# Advertising       0.269507  -0.024199  0.058995     1.000000    0.265652
# Population        0.050471  -0.094707 -0.007877     0.265652    1.000000
# Price            -0.444951   0.584848 -0.056698     0.044537   -0.012144
# Age              -0.231815  -0.100239 -0.004670    -0.004557   -0.042663
# Education        -0.051955   0.025197 -0.056855    -0.033594   -0.106378
# ShelveLoc_Bad    -0.393167  -0.035393  0.072017    -0.035217    0.039902
# ShelveLoc_Good    0.500510   0.026386 -0.012657     0.056149    0.007789
# ShelveLoc_Medium -0.073999   0.008683 -0.051392    -0.015929   -0.040640
# Urban_No          0.015419  -0.066594 -0.037967    -0.042035    0.052025
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(9,6))
ax = sns.kdeplot(data1['Sales'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()

# %% [markdown]
# The data is Skwed on the right
#
# The data has negative Kurtosis

# %%
data1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
data1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
num_columns = data1.select_dtypes(exclude='object').columns.tolist()
num_data = data1[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#              Sales  CompPrice    Income  Advertising  Population     Price  \
# skewness  0.185560  -0.042755  0.049444     0.639586   -0.051227 -0.125286
# kurtosis -0.080877   0.041666 -1.085289    -0.545118   -1.202318  0.451885
#
#                Age  Education  ShelveLoc_Bad  ShelveLoc_Good  \
# skewness -0.077182   0.044007       1.222149        1.410901
# kurtosis -1.134392  -1.298332      -0.508921       -0.009431
#
#           ShelveLoc_Medium  Urban_No  Urban_Yes     US_No    US_Yes
# skewness         -0.191582  0.902426  -0.902426  0.608327 -0.608327
# kurtosis         -1.973187 -1.191610  -1.191610 -1.638154 -1.638154

# %% [markdown]
# # Random Forest

# %% [markdown]
# Since the target variable is continious, we create a class of the value based on the mean
#
# <= 7.49 == "Small" and > 7.49 == "large"

# %%
data1["sales"]="small"
data1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
data1.loc[data1["Sales"]>7.49,"sales"]="large"
data1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
data1.drop(["Sales"],axis=1,inplace=True)
data1
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# ...

# %%
X = data1.iloc[:,0:14]
Y = data1.iloc[:,14]

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# ...

# %%
Y
# Out:
# 0      large
# 1      large
# 2      large
# 3      small
# 4      small
#        ...
# 395    large
# 396    small
# 397    small
# 398    small
# 399    large
# Name: sales, Length: 400, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# %%
model = RF(n_estimators=10, max_depth = 3) 
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
pred_train = model.predict(x_train)

# %%
pred_train
# Out:
# array(['small', 'large', 'small', 'large', 'large', 'small', 'small',
#        'small', 'large', 'large', 'small', 'large', 'large', 'large',
#        'small', 'large', 'small', 'large', 'large', 'small', 'small',
#        'large', 'small', 'small', 'small', 'small', 'large', 'large',
#        'large', 'small', 'large', 'large', 'large', 'small', 'small',
#        'large', 'large', 'large', 'large', 'large', 'small', 'large',
#        'small', 'small', 'large', 'large', 'small', 'small', 'large',
#        'large', 'large', 'small', 'large', 'small', 'large', 'small',
#        'large', 'small', 'small', 'large', 'large', 'large', 'small',
#        'large', 'small', 'large', 'large', 'large', 'small', 'small',
#        'large', 'small', 'large', 'large', 'small', 'small', 'small',
#        'large', 'small', 'small', 'small', 'large', 'large', 'large',
#        'small', 'small', 'small', 'small', 'large', 'small', 'large',
# ...

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.8388888888888889

# %%
confusion_matrix(y_train,pred_train)
# Out:
# array([[145,  36],
#        [ 22, 157]], dtype=int64)

# %%
pred_test = model.predict(x_test)

# %%
pred_test
# Out:
# array(['large', 'large', 'large', 'small', 'large', 'large', 'large',
#        'small', 'small', 'small', 'small', 'small', 'large', 'large',
#        'small', 'small', 'large', 'large', 'small', 'small', 'small',
#        'large', 'large', 'large', 'small', 'large', 'small', 'small',
#        'large', 'small', 'large', 'large', 'large', 'small', 'small',
#        'large', 'small', 'small', 'small', 'large'], dtype=object)

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.8

# %%
confusion_matrix(y_test,pred_test)
# Out:
# array([[15,  3],
#        [ 5, 17]], dtype=int64)

# %%
df = pd.DataFrame({'Actual':y_test,'Predicted':pred_test})
df
# Out:
#     Actual Predicted
# 132  large     large
# 309  large     large
# 341  small     large
# 196  small     small
# 246  small     large
# 60   large     large
# 155  large     large
# 261  small     small
# 141  small     small
# 214  small     small
# 37   small     small
# 134  small     small
# 113  small     large
# 348  large     large
# 12   small     small
# 59   small     small
# 293  large     large
# 140  small     large
# 206  small     small
# 199  small     small
# 176  small     small
# 268  small     large
# 124  large     large
# 344  large     large
# 175  large     small
# 313  large     large
# 78   small     small
# 15   large     small
# 286  large     large
# 102  small     small
# 170  large     large
# 303  large     large
# 334  large     large
# 225  small     small
# 65   small     small
# 76   large     large
# 90   small     small
# 173  small     small
# 179  large     small
# 399  large     large

# %% [markdown]
# # Conclusion
#
# Since the accuracy of the Training set is 100% we test the accurancy on the test data which is 80%

# %% [markdown]
# As seen in the confusion matrix of Test data 32 instances are presdected correctly and 8 instances are not

# %% [markdown]
# # FRAUD_CHECK.CSV

# %% [markdown]
# # 1 - Business Problem
#
# Use random forest model to prepare a model on fraud data
# treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %% [markdown]
# # 2 - Data collection and description

# %%
data = pd.read_csv(r'Fraud_check.csv')

# %%
data
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# ...

# %%
data1 = data.copy()

# %%
data1 = pd.get_dummies(data1, columns = ['Undergrad','Marital.Status','Urban'])

# %% [markdown]
# # EDA

# %%
data1.shape
# Out:
# (600, 10)

# %%
data1.describe().T
# Out:
#                          count           mean           std      min  \
# Taxable.Income           600.0   55208.375000  26204.827597  10003.0
# City.Population          600.0  108747.368333  49850.075134  25779.0
# Work.Experience          600.0      15.558333      8.842147      0.0
# Undergrad_NO             600.0       0.480000      0.500017      0.0
# Undergrad_YES            600.0       0.520000      0.500017      0.0
# Marital.Status_Divorced  600.0       0.315000      0.464903      0.0
# Marital.Status_Married   600.0       0.323333      0.468139      0.0
# Marital.Status_Single    600.0       0.361667      0.480884      0.0
# Urban_NO                 600.0       0.496667      0.500406      0.0
# Urban_YES                600.0       0.503333      0.500406      0.0
#
#                               25%       50%        75%       max
# Taxable.Income           32871.50   55074.5   78611.75   99619.0
# City.Population          66966.75  106493.5  150114.25  199778.0
# ...

# %%
data1.isnull().sum()
# Out:
# Taxable.Income             0
# City.Population            0
# Work.Experience            0
# Undergrad_NO               0
# Undergrad_YES              0
# Marital.Status_Divorced    0
# Marital.Status_Married     0
# Marital.Status_Single      0
# Urban_NO                   0
# Urban_YES                  0
# dtype: int64

# %% [markdown]
# Correlation

# %%
cor = data1.corr()
cor
# Out:
#                          Taxable.Income  City.Population  Work.Experience  \
# Taxable.Income                 1.000000        -0.064387        -0.001818
# City.Population               -0.064387         1.000000         0.013135
# Work.Experience               -0.001818         0.013135         1.000000
# Undergrad_NO                   0.049232        -0.079579         0.005362
# Undergrad_YES                 -0.049232         0.079579        -0.005362
# Marital.Status_Divorced        0.062099         0.004925        -0.014833
# Marital.Status_Married        -0.100611        -0.007035         0.033347
# Marital.Status_Single          0.037910         0.002087        -0.018123
# Urban_NO                      -0.070628         0.040098         0.094559
# Urban_YES                      0.070628        -0.040098        -0.094559
#
#                          Undergrad_NO  Undergrad_YES  Marital.Status_Divorced  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(9,6))
ax = sns.kdeplot(data1['Taxable.Income'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()

# %%
data1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
data1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
num_columns = data1.select_dtypes(exclude='object').columns.tolist()
num_data = data1[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#           Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# skewness        0.030015         0.125009         0.018529      0.080265
# kurtosis       -1.199782        -1.120154        -1.167524     -2.000236
#
#           Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# skewness      -0.080265                 0.798526                0.757286
# kurtosis      -2.000236                -1.366924               -1.431300
#
#           Marital.Status_Single  Urban_NO  Urban_YES
# skewness               0.577254  0.013367  -0.013367
# kurtosis              -1.672364 -2.006521  -2.006521

# %% [markdown]
# # Random Forest
#
# Since the target variable is continious, we create a class of the value based on the
#
# taxable_income <= 30000 as "Risky" and others are "Good"

# %%
data1['tax'] = 'Good'
data1
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
data1.loc[data1['Taxable.Income']<=30000,"tax"]="Risky"
data1
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
data1.drop(['Taxable.Income'],axis=1,inplace=True)

# %%
data1
# Out:
#      City.Population  Work.Experience  Undergrad_NO  Undergrad_YES  \
# 0              50047               10             1              0
# 1             134075               18             0              1
# 2             160205               30             1              0
# 3             193264               15             0              1
# 4              27533               28             1              0
# ..               ...              ...           ...            ...
# 595            39492                7             0              1
# 596            55369                2             0              1
# 597           154058                0             1              0
# 598           180083               17             0              1
# 599           158137               16             1              0
#
#      Marital.Status_Divorced  Marital.Status_Married  Marital.Status_Single  \
# 0                          0                       0                      1
# ...

# %%
X = data1.iloc[:,0:9]
Y = data1.iloc[:,9]

# %%
X
# Out:
#      City.Population  Work.Experience  Undergrad_NO  Undergrad_YES  \
# 0              50047               10             1              0
# 1             134075               18             0              1
# 2             160205               30             1              0
# 3             193264               15             0              1
# 4              27533               28             1              0
# ..               ...              ...           ...            ...
# 595            39492                7             0              1
# 596            55369                2             0              1
# 597           154058                0             1              0
# 598           180083               17             0              1
# 599           158137               16             1              0
#
#      Marital.Status_Divorced  Marital.Status_Married  Marital.Status_Single  \
# 0                          0                       0                      1
# ...

# %%
Y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: tax, Length: 600, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.1,random_state=0)

# %%
model = RF(n_estimators=10, max_depth = 3) 
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
pred_train = model.predict(x_train)

# %%
pred_train
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
# ...

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.8037037037037037

# %%
confusion_matrix(y_train,pred_train)
# Out:
# array([[433,   0],
#        [106,   1]], dtype=int64)

# %%
pred_test = model.predict(x_test)
pred_test
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good'], dtype=object)

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.7166666666666667

# %%
confusion_matrix(y_test,pred_test)
# Out:
# array([[43,  0],
#        [17,  0]], dtype=int64)

# %%
df = pd.DataFrame({'Actual':y_test,'Predicted':pred_test})
df
# Out:
#     Actual Predicted
# 434  Risky      Good
# 122  Risky      Good
# 224   Good      Good
# 479   Good      Good
# 205  Risky      Good
# 569   Good      Good
# 432   Good      Good
# 526  Risky      Good
# 439  Risky      Good
# 162   Good      Good
# 315  Risky      Good
# 400   Good      Good
# 173   Good      Good
# 283   Good      Good
# 48   Risky      Good
# 457  Risky      Good
# 482   Good      Good
# 85   Risky      Good
# 187   Good      Good
# 365   Good      Good
# 524  Risky      Good
# 480   Good      Good
# 346  Risky      Good
# 194  Risky      Good
# 477   Good      Good
# 186   Good      Good
# 299   Good      Good
# 495   Good      Good
# 446  Risky      Good
# 594   Good      Good
# 348   Good      Good
# 499   Good      Good
# 366   Good      Good
# 14    Good      Good
# 127   Good      Good
# 580   Good      Good
# 92    Good      Good
# 333  Risky      Good
# 200   Good      Good
# 1     Good      Good
# 343   Good      Good
# 312   Good      Good
# ...

# %% [markdown]
# # Conclusion
#
# Since the accuracy of the Training set is 100% we test the accurancy on the test data which is 71%
#
# As seen in the confusion matrix of Test data 43 instances are presdected correctly and 17 instances are not
